# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('student_data.csv')

# %%
num_cols = df.select_dtypes(include=['int64','float64']).describe()
num_cols.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='str')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # Ploting of Numerical Data

# %% [markdown]
# ## Histogram of some numerical data

# %%
plt.hist(df['age'],bins = 15)
plt.show()

# %%
plt.hist(df['Medu'],bins = 15)
plt.show()

# %%
plt.hist(df['Fedu'],bins = 15)
plt.show()

# %%
plt.hist(df['traveltime'],bins = 15)
plt.show()

# %%
plt.hist(df['G1'],bins = 15)
plt.show()

# %%
plt.hist(df['G2'],bins = 15)
plt.show()

# %%
plt.hist(df['G3'],bins = 15)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(df['age'])
plt.show()

# %%
plt.boxplot(df['Medu'])
plt.show()

# %%
plt.boxplot(df['Fedu'])
plt.show()

# %%
plt.boxplot(df['traveltime'])
plt.show()

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df['age'],kde =True)
# Out:
# C:\Users\VINAY_SHARMA\AppData\Local\Temp\ipykernel_21004\2875817476.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],kde =True)

# %%
sns.distplot(df['Medu'],kde =True)
# Out:
# C:\Users\VINAY_SHARMA\AppData\Local\Temp\ipykernel_21004\3150866074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Medu'],kde =True)
# <Axes: xlabel='Medu', ylabel='Density'>

# %%
sns.distplot(df['Fedu'],kde =True)
# Out:
# C:\Users\VINAY_SHARMA\AppData\Local\Temp\ipykernel_21004\2205006353.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fedu'],kde =True)
# <Axes: xlabel='Fedu', ylabel='Density'>

# %%
sns.distplot(df['traveltime'],kde =True)
# Out:
# C:\Users\VINAY_SHARMA\AppData\Local\Temp\ipykernel_21004\112726921.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['traveltime'],kde =True)
# <Axes: xlabel='traveltime', ylabel='Density'>

# %%
cat_cols = df.select_dtypes(['str'])
cat_cols.columns
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='str')

# %% [markdown]
# # Ploting of Categorical Data

# %% [markdown]
# ## Countplot

# %%
sns.countplot(df['school'])
# Out:
# <Axes: xlabel='count', ylabel='school'>

# %%
sns.countplot(df['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(df['address'])
# Out:
# <Axes: xlabel='count', ylabel='address'>

# %%
sns.countplot(df['famsize'])
# Out:
# <Axes: xlabel='count', ylabel='famsize'>

# %% [markdown]
# ## Piechart

# %%
df['school'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df['sex'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df['address'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
df['famsize'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
print(float(df['age'].min()))
print(float(df['age'].max()))
print(float(round(df['age'].mean(),5)))
print(float(df['age'].skew()))
# Out:
# 15.0
# 22.0
# 16.6962
# 0.46627016141836425

# %%
print(float(df['Medu'].min()))
print(float(df['Medu'].max()))
print(float(round(df['Medu'].mean(),5)))
print(float(df['Medu'].skew()))
# Out:
# 0.0
# 4.0
# 2.74937
# -0.31838068845785517

# %%
print(float(df['Fedu'].min()))
print(float(df['Fedu'].max()))
print(float(round(df['Fedu'].mean(),5)))
print(float(df['Fedu'].skew()))
# Out:
# 0.0
# 4.0
# 2.52152
# -0.03167209443510635

# %%
print(float(df['traveltime'].min()))
print(float(df['traveltime'].max()))
print(float(round(df['traveltime'].mean(),5)))
print(float(df['traveltime'].skew()))
# Out:
# 1.0
# 4.0
# 1.4481
# 1.6070291037557645
